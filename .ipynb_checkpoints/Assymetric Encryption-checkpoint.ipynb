# %%
import matplotlib.pyplot as plt
import cv2 
import numpy as np
# %matplotlib inline

# %%
def keygen(x,r,size):
    key=[]
    for i in range(size):
        x = r*x*(1-x)
        key.append(int((x*pow(10,16))%256))
        
    return key

# %%
def subimage(img,r):
    h = img.shape[0]
    w = img.shape[1]
    z = 0
    key = keygen(0.01,r,h*w)
    enimg = np.zeros(shape = [h,w,3],dtype = np.uint8)
    for i in range(h):
        for j in range(w):
            enimg[i,j] = img[i,j]^key[z] #pixel value xor with key value
            z+=1
    return enimg

# %%
def desubimage(enimg,r):
    h = img.shape[0]
    w = img.shape[1]
    z = 0
    key = keygen(0.01,r,h*w)    
    decimg = np.zeros(shape = [h,w,3],dtype= np.uint8)
    for i in range(h):
        for j in range(w):
            decimg[i,j] = enimg[i,j]^key[z]
            z+=1
    return decimg

# %%
def indexgen(x,r,n):
    index = []
    k = []
    for i in range(n):
        x = r*x*(1-x)
        k.append(x)
        index.append(i)
    # below the chaotic keys keys are arranget in ascending order which scrambles index positions
    for i in range(n):
        for j in range(n): 
            if(k[i]>k[j]):
                k[i],k[j] = k[j],k[i]
                index[i] , index[j] = index[j],index[i]
    return index

# %%
def shuffleimage(img,index,x,y):
    ecrimg = np.zeros(shape = [x,y,3],dtype = np.uint8)
    for i in range(x):
        k = 0
        for j in range(y):
            try:
                ecrimg[i][j] = img[i][index[k]]
                k+=1
            except:
                pass
    return ecrimg

# %%
def final_shuffle(img,r):
    h = img.shape[0]
    w = img.shape[1]
    eimg = np.zeros(shape = [w,h],dtype = np.uint8)
    #shuffling pixels row wise
    key = indexgen(0.1,r,w)
    eimg = shuffleimage(img,key,h,w)
    return eimg

# %%
img = cv2.imread('b.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
h = img.shape[0]
w = img.shape[1]

# %%
enimg = subimage(img,3.995)
plt.imshow(enimg)

# %%
decimg=desubimage(enimg,3.995)
plt.imshow(decimg)

# %% [markdown]
# ## Shuffling function

# %%
eimg = final_shuffle(img,3.995)

# %%
plt.imshow(eimg)

# %%
def deshuffle(img,index,x,y):
    dimg = np.zeros(shape = [y,x,3],dtype = np.uint8)
    for i in range(x):
        k=0
        for j in range(y):
            try:
                dimg[i][index[k]] = img[i][j]
                k=k+1
            except:
                pass
    return dimg

# %%
ecrimg2 = np.zeros(shape = [w,h],dtype = np.uint8)
key = indexgen(0.1,3.995,h)
ecrimg2 = deshuffle(eimg,key,h,w)

# %%
key = indexgen(0.1,3.995,w)
ecrimg2 = deshuffle(eimg,key,w,h)

# %%
plt.imshow(ecrimg2)
